# %% [markdown]
# # Parse Vplus Browser PR + Package Sheets

# %%
import pandas as pd
from pathlib import Path
# excel_file = Path(r'E:\nextcloud\py_knecht\RenderKnecht\_TestDocs\20171109_MBV_A3-Familie_AoA_MY2018.xlsx')
excel_file = Path(r'I:\Nextcloud\py\py_knecht\RenderKnecht\_TestDocs\20171109_MBV_A3-Familie_AoA_MY2018.xlsx')

# %% [markdown]
# 1. Parse excel file, skipping first 2 rows, combining row 2+3 as header

# %%
ef = pd.ExcelFile(excel_file)

# %%
ef.sheet_names
# Out:
# ['Modelle', 'Farben 8V', 'PR-Nummern', 'Pakete', 'Parameter']

# %%
df = pd.read_excel(excel_file, sheet_name='PR-Nummern', skiprows=[0,1], header=[0,1])
df.head(3)
# Out:
#           PR-Familie      PR-FamilienText          PR-Nummer  \
#   Unnamed: 0_level_1   Unnamed: 1_level_1 Unnamed: 2_level_1
# 0                AAU  Aktionsausführungen                NaN
# 1                NaN                  NaN                E0A
# 2                NaN                  NaN                E3T
#
#                       Text             Modell  8VM
#         Unnamed: 3_level_1 Unnamed: 4_level_1  B8L  RWY  S1Y
# 0                      NaN                NaN  NaN  NaN  NaN
# 1  Keine Aktionsausführung                NaN    L    L    L
# 2                   "Life"                NaN    P    -    -

# %% [markdown]
# 2. Join the header rows containing the model string spread across two rows

# %%
#  Join Header Rows

def join_header_rows(rows):
    first_row, second_row = rows
    
    if second_row.startswith('Unnamed'):
        return first_row
    else:
        return first_row + second_row
    
df.columns = df.columns.map(join_header_rows)
df.head(3)
# Out:
#   PR-Familie      PR-FamilienText PR-Nummer                     Text  Modell  \
# 0        AAU  Aktionsausführungen       NaN                      NaN     NaN
# 1        NaN                  NaN       E0A  Keine Aktionsausführung     NaN
# 2        NaN                  NaN       E3T                   "Life"     NaN
#
#   8VMB8L 8VMRWY 8VMS1Y
# 0    NaN    NaN    NaN
# 1      L      L      L
# 2      P      -      -

# %% [markdown]
# 3. Clean up empty rows and columns

# %%
# Remove empty rows
df.dropna(thresh=2, inplace=True)

# Remove empty descriptive column 'Modell'
df.drop(columns=['Modell'], inplace=True)

df.head(10)
# Out:
#    PR-Familie                                    PR-FamilienText PR-Nummer  \
# 0         AAU                                Aktionsausführungen       NaN
# 1         NaN                                                NaN       E0A
# 2         NaN                                                NaN       E3T
# 4         ABR                         Abschließbare Radschrauben       NaN
# 5         NaN                                                NaN       1PA
# 7         AED  Fahrzeugklassendifferenzierung Aggregate / Pla...       NaN
# 8         NaN                                                NaN       7LJ
# 10        AER                                       Abgasendrohr       NaN
# 11        NaN                                                NaN       0P0
# 12        NaN                                                NaN       0P6
#
#                                        Text 8VMB8L 8VMRWY 8VMS1Y
# 0                                       NaN    NaN    NaN    NaN
# 1                   Keine Aktionsausführung      L      L      L
# 2                                    "Life"      P      -      -
# 4                                       NaN    NaN    NaN    NaN
# 5                     Radschrauben Standard      L      L      L
# 7                                       NaN    NaN    NaN    NaN
# 8   Fahrzeugklassen-Differenzierung 8V0/8VC      L      L      L
# 10                                      NaN    NaN    NaN    NaN
# 11                            Abgasendrohre      L      L      L
# 12                      RS-Sportabgasanlage      -      P      -

# %%
# Forward fill PR-Family column and convert to category
df['PR-Familie'] = df['PR-Familie'].ffill().astype('category')

# Forward fill PR-Family Description column and convert to category
df['PR-FamilienText'] = df['PR-FamilienText'].ffill().astype('category')

df.head(10)
# Out:
#    PR-Familie                                    PR-FamilienText PR-Nummer  \
# 0         AAU                                Aktionsausführungen       NaN
# 1         AAU                                Aktionsausführungen       E0A
# 2         AAU                                Aktionsausführungen       E3T
# 4         ABR                         Abschließbare Radschrauben       NaN
# 5         ABR                         Abschließbare Radschrauben       1PA
# 7         AED  Fahrzeugklassendifferenzierung Aggregate / Pla...       NaN
# 8         AED  Fahrzeugklassendifferenzierung Aggregate / Pla...       7LJ
# 10        AER                                       Abgasendrohr       NaN
# 11        AER                                       Abgasendrohr       0P0
# 12        AER                                       Abgasendrohr       0P6
#
#                                        Text 8VMB8L 8VMRWY 8VMS1Y
# 0                                       NaN    NaN    NaN    NaN
# 1                   Keine Aktionsausführung      L      L      L
# 2                                    "Life"      P      -      -
# 4                                       NaN    NaN    NaN    NaN
# 5                     Radschrauben Standard      L      L      L
# 7                                       NaN    NaN    NaN    NaN
# 8   Fahrzeugklassen-Differenzierung 8V0/8VC      L      L      L
# 10                                      NaN    NaN    NaN    NaN
# 11                            Abgasendrohre      L      L      L
# 12                      RS-Sportabgasanlage      -      P      -

# %%
# Drop rows without PR
df.dropna(subset=['PR-Nummer'], inplace=True)

df.head(10)
# Out:
#    PR-Familie                                    PR-FamilienText PR-Nummer  \
# 1         AAU                                Aktionsausführungen       E0A
# 2         AAU                                Aktionsausführungen       E3T
# 5         ABR                         Abschließbare Radschrauben       1PA
# 8         AED  Fahrzeugklassendifferenzierung Aggregate / Pla...       7LJ
# 11        AER                                       Abgasendrohr       0P0
# 12        AER                                       Abgasendrohr       0P6
# 15        AGM                                       Abgaskonzept       0GT
# 16        AGM                                       Abgaskonzept       7GB
# 17        AGM                                       Abgaskonzept       7MU
# 20        AHV                                 Anhängevorrichtung       1D0
#
#                                        Text 8VMB8L 8VMRWY 8VMS1Y
# 1                   Keine Aktionsausführung      L      L      L
# 2                                    "Life"      P      -      -
# 5                     Radschrauben Standard      L      L      L
# 8   Fahrzeugklassen-Differenzierung 8V0/8VC      L      L      L
# 11                            Abgasendrohre      L      L      L
# 12                      RS-Sportabgasanlage      -      P      -
# 15                      Abgaskonzept, SULEV      L      -      -
# 16                     Abgaskonzept, ULEV 2      -      -      L
# 17           Abgaskonzept, LEV3 / Tier3 125      -      L      -
# 20                  Ohne Anhängevorrichtung      L      L      L

# %% [markdown]
# 4. Example for extracting a trim line

# %%
model = df[['PR-Familie', 'PR-FamilienText', 'PR-Nummer', 'Text', '8VMB8L']]
model.set_index(['PR-Familie'], inplace=True)

trim = model[model['8VMB8L'].str.match('L')]
trim.head(10)
# Out:
#                                               PR-FamilienText PR-Nummer  \
# PR-Familie
# AAU                                       Aktionsausführungen       E0A
# ABR                                Abschließbare Radschrauben       1PA
# AED         Fahrzeugklassendifferenzierung Aggregate / Pla...       7LJ
# AER                                              Abgasendrohr       0P0
# AGM                                              Abgaskonzept       0GT
# AHV                                        Anhängevorrichtung       1D0
# AIB                                                    Airbag       4UB
# AKB                   Aktivkohlebehälter / Ottopartikelfilter       1E7
# ALG                                              Ablagenpaket       QE0
# ASE                                  Außenspiegel-Einstellung       6XD
#
#                                                          Text 8VMB8L
# PR-Familie
# AAU                                   Keine Aktionsausführung      L
# ABR                                     Radschrauben Standard      L
# AED                   Fahrzeugklassen-Differenzierung 8V0/8VC      L
# AER                                             Abgasendrohre      L
# AGM                                       Abgaskonzept, SULEV      L
# AHV                                   Ohne Anhängevorrichtung      L
# AIB                                            Airbag für NAR      L
# AKB         Aktivkohlebehälter ORVR,für verschärftes Verda...      L
# ALG                                     Ohne Ablagenpaket/box      L
# ASE           Außenspiegel elektrisch einstell- und beheizbar      L

# %% [markdown]
# 5. Example for extracting options

# %%
options = model[model['8VMB8L'].str.match('E')]
options.head(10)
# Out:
#                        PR-FamilienText PR-Nummer  \
# PR-Familie
# COC                      ABE-Nachträge       C01
# COC                      ABE-Nachträge       C02
# GKH         Gewichtsklasse Hinterachse       0YA
# GKH         Gewichtsklasse Hinterachse       0YB
# GKH         Gewichtsklasse Hinterachse       0YC
# GKH         Gewichtsklasse Hinterachse       0YD
# GKH         Gewichtsklasse Hinterachse       0YE
# GKH         Gewichtsklasse Hinterachse       0YF
# GKH         Gewichtsklasse Hinterachse       0YG
# GKH         Gewichtsklasse Hinterachse       0YH
#
#                                                          Text 8VMB8L
# PR-Familie
# COC                                Betriebserlaubnis Nachtrag      E
# COC                                Betriebserlaubnis Nachtrag      E
# GKH         Gewichtsbereich 1 nur Einbausteuerung keine Be...      E
# GKH         Gewichtsbereich 2 nur Einbausteuerung keine Be...      E
# GKH         Gewichtsbereich 3 nur Einbausteuerung keine Be...      E
# GKH         Gewichtsbereich 4 nur Einbausteuerung keine Be...      E
# GKH         Gewichtsbereich 5 nur Einbausteuerung keine Be...      E
# GKH         Gewichtsbereich 6 nur Einbausteuerung keine Be...      E
# GKH         Gewichtsbereich 7 nur Einbausteuerung keine Be...      E
# GKH         Gewichtsbereich 8 nur Einbausteuerung keine Be...      E
